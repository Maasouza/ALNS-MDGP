# %%
import matplotlib.pyplot as plt 
from decimal import Decimal
import os

# %%
file_name = "start_sol_all_instances.out"

file = open("start_sol_all_instances.out")

file.readline()


instance_info = { "n010":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }}, 
                 "n012":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n030":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n060":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n120":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n240":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n480":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }},
                 "n960":{"random":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy1":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy2":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy3":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }, "greedy4":{"mean_best" : 0.0, "exec_time":0.0, "repair_time":0.0 }}}


for line in file:

    instance_size, alg, mean_best, exec_time, repair_time = line.split()

    instance_size = instance_size.split('_')[1]
    instance_size
    instance_info[instance_size][alg]['mean_best'] += float(mean_best)
    instance_info[instance_size][alg]['exec_time'] += float(exec_time)
    instance_info[instance_size][alg]['repair_time'] += float(repair_time)

x_axis = []

random  = [[],[]]
greedy1 = [[],[]]
greedy2 = [[],[]]
greedy3 = [[],[]]
greedy4 = [[],[]]
for instance, algs in sorted(list(instance_info.items())):
    x_axis.append(instance)
    print("\\midrule")
    for alg, info in sorted(list(algs.items())):
        print(instance+" & "+ alg + " & " + "{:.3E}".format(Decimal(info['exec_time'])) +" & "+ "{:.3E}".format(Decimal(info['repair_time']))+" & "+ "{:.3E}".format(Decimal(info['repair_time']/info['exec_time']))+"\\\\")
        if(alg == 'random'):
            random[0].append(info['exec_time'])
            random[1].append(info['repair_time'])
        elif(alg == 'greedy1'):
            greedy1[0].append(info['exec_time'])
            greedy1[1].append(info['repair_time'])
        elif(alg == 'greedy2'):
            greedy2[0].append(info['exec_time'])
            greedy2[1].append(info['repair_time'])
        elif(alg == 'greedy3'):
            greedy3[0].append(info['exec_time'])
            greedy3[1].append(info['repair_time'])
        elif(alg == 'greedy4'):
            greedy4[0].append(info['exec_time'])
            greedy4[1].append(info['repair_time'])
# Out:
# \midrule
# n010 & greedy1 & 7.178E-3 & 4.699E-4 & 6.546E-2\\
# n010 & greedy2 & 4.926E-3 & 4.309E-4 & 8.746E-2\\
# n010 & greedy3 & 1.972E-2 & 4.278E-4 & 2.170E-2\\
# n010 & greedy4 & 1.861E-2 & 4.723E-4 & 2.537E-2\\
# n010 & random & 7.214E-3 & 4.893E-4 & 6.783E-2\\
# \midrule
# n012 & greedy1 & 1.114E-2 & 1.130E-3 & 1.014E-1\\
# n012 & greedy2 & 7.304E-3 & 1.082E-3 & 1.481E-1\\
# n012 & greedy3 & 3.162E-2 & 9.212E-4 & 2.913E-2\\
# n012 & greedy4 & 2.928E-2 & 6.761E-4 & 2.309E-2\\
# n012 & random & 1.122E-2 & 9.634E-4 & 8.589E-2\\
# \midrule
# n030 & greedy1 & 3.424E-2 & 2.745E-3 & 8.017E-2\\
# n030 & greedy2 & 1.396E-2 & 2.545E-3 & 1.823E-1\\
# n030 & greedy3 & 6.964E-2 & 1.359E-3 & 1.952E-2\\
# n030 & greedy4 & 6.608E-2 & 1.107E-3 & 1.675E-2\\
# n030 & random & 1.723E-2 & 1.449E-3 & 8.410E-2\\
# \midrule
# n060 & greedy1 & 9.262E-2 & 2.975E-3 & 3.212E-2\\
# n060 & greedy2 & 2.262E-2 & 2.636E-3 & 1.165E-1\\
# n060 & greedy3 & 1.311E-1 & 1.471E-3 & 1.122E-2\\
# ...

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Media de Tempo(s) - Random")
plt.bar(x_axis, random[0], label="Execution time")
plt.bar(x_axis, random[1], label="Repair Time")
plt.xlabel('Instancia', fontsize=12)
plt.ylabel('Tempo(s)', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("random.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Media de Tempo(s) - Greedy1")
plt.bar(x_axis, greedy1[0], label="Execution time")
plt.bar(x_axis, greedy1[1], label="Repair Time")
plt.xlabel('Instancia', fontsize=12)
plt.ylabel('Tempo(s)', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("greedy1.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Media de Tempo(s) - Greedy2")
plt.bar(x_axis, greedy2[0], label="Execution time")
plt.bar(x_axis, greedy2[1], label="Repair Time")
plt.xlabel('Instancia', fontsize=12)
plt.ylabel('Tempo(s)', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("greedy2.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Media de Tempo(s) - Greedy3")
plt.bar(x_axis, greedy3[0], label="Execution time")
plt.bar(x_axis, greedy3[1], label="Repair Time")
plt.xlabel('Instancia', fontsize=12)
plt.ylabel('Tempo(s)', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("greedy3.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Media de Tempo(s) - Greedy4")
plt.bar(x_axis, greedy4[0], label="Execution time")
plt.bar(x_axis, greedy4[1], label="Repair Time")
plt.xlabel('Instancia', fontsize=12)
plt.ylabel('Tempo(s)', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("greedy4.png")
