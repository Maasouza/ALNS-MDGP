# %%
import matplotlib.pyplot as plt 
from decimal import Decimal
import os

# %%
file_name = "start_sol_all_instances.out"



instance_info = {"n010_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }}, 
                 "n012_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n030_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n060_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n120_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n240_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n480_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n960_ds":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n010_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }}, 
                 "n012_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n030_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n060_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n120_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n240_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n480_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }},
                 "n960_ss":{"insertion":{"random":0.0, "greedy1":0.0, "greedy2":0.0, "greedy3":0.0, "greedy4":0.0 ,"worst": 0.0}, "removal":{"random":0.0, "biased": 0.0 ,"greedy": 0.0 , "pair": 0.0, "shaw":0.0 }}}


path = './'
files = []
for r, d, f in os.walk(path):
    for file in f:
        if any(i in file for i in ['normal_']):
            files.append(os.path.join(r, file))

for file in files:
    f = open(file)
    instance_size = f.readline().split()[-1]
    instance_size = instance_size.split('_')[1] +"_"+ instance_size.split('_')[2] 

    f.readline()
    f.readline()
    f.readline()
    ####Removal
    instance_info[instance_size]['removal']['random'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['removal']['biased'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['removal']['greedy'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['removal']['pair'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['removal']['shaw'] +=  float(f.readline().split()[-1])
    f.readline()
    #####Insertion
    instance_info[instance_size]['insertion']['random'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['insertion']['greedy1'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['insertion']['greedy2'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['insertion']['greedy3'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['insertion']['greedy4'] +=  float(f.readline().split()[-1])
    instance_info[instance_size]['insertion']['worst'] +=  float(f.readline().split()[-1])


###
x_axis_ss = []
x_axis_ds = []

insertion_axis_ss = [[], [], [], [], [], []]

removal_axis_ss = [[], [], [], [], []]

insertion_axis_ds = [[], [], [], [], [], []]

removal_axis_ds = [[], [], [], [], []]

for instance, algs in sorted(list(instance_info.items())):
    if "ds" in instance:
        x_axis_ds.append(instance)
        for alg, info in sorted(list(algs.items())):
            if alg == 'insertion':
                denominador = info['random'] + info['greedy1'] + info['greedy2'] + info['greedy3'] + info['greedy4'] + info['worst']
                insertion_axis_ds[0].append(info['random']/denominador) 
                insertion_axis_ds[1].append(info['greedy1']/denominador)
                insertion_axis_ds[2].append(info['greedy2']/denominador)
                insertion_axis_ds[3].append(info['greedy3']/denominador)
                insertion_axis_ds[4].append(info['greedy4']/denominador)
                insertion_axis_ds[5].append(info['worst']/denominador)
            elif alg == 'removal':
                denominador = info['random'] + info['greedy'] + info['biased'] + info['pair'] + info['shaw']
                removal_axis_ds[0].append(info['random']/denominador)
                removal_axis_ds[1].append(info['biased']/denominador)
                removal_axis_ds[2].append(info['greedy']/denominador)
                removal_axis_ds[3].append(info['pair']/denominador)
                removal_axis_ds[4].append(info['shaw']/denominador)
    else:
        x_axis_ss.append(instance)
        for alg, info in sorted(list(algs.items())):
            if alg == 'insertion':
                denominador = info['random'] + info['greedy1'] + info['greedy2'] + info['greedy3'] + info['greedy4'] + info['worst']
                insertion_axis_ss[0].append(info['random']/denominador) 
                insertion_axis_ss[1].append(info['greedy1']/denominador)
                insertion_axis_ss[2].append(info['greedy2']/denominador)
                insertion_axis_ss[3].append(info['greedy3']/denominador)
                insertion_axis_ss[4].append(info['greedy4']/denominador)
                insertion_axis_ss[5].append(info['worst']/denominador)
            elif alg == 'removal':
                denominador = info['random'] + info['greedy'] + info['biased'] + info['pair'] + info['shaw']
                removal_axis_ss[0].append(info['random']/denominador)
                removal_axis_ss[1].append(info['biased']/denominador)
                removal_axis_ss[2].append(info['greedy']/denominador)
                removal_axis_ss[3].append(info['pair']/denominador)
                removal_axis_ss[4].append(info['shaw']/denominador)

# %%
pallet = [ (13.0/255,154.0/255,189.0/255), (14.0/255,55.0/255,111.0/255), (255/255,33.0/255,33.0/255),(250.0/255, 78.0/255, 10.0/255) ,(255.0/255, 95.0/255, 127.0/255), (170.0/255,215.0/255,44.0/255)  ]

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Operadores de Insercao")
width = 0.5

plt.bar(x_axis_ds, insertion_axis_ds[0] , width, label = "random", color = [pallet[0]])
plt.bar(x_axis_ds, insertion_axis_ds[1], width, bottom=insertion_axis_ds[0], label="greedy1", color = [pallet[1]])

gap = [sum(x) for x in zip(insertion_axis_ds[0],insertion_axis_ds[1])]
plt.bar(x_axis_ds, insertion_axis_ds[2], width, bottom=gap, label="greedy2",color = [pallet[2]])

gap = [sum(x) for x in zip(insertion_axis_ds[0],insertion_axis_ds[1], insertion_axis_ds[2])]
plt.bar(x_axis_ds, insertion_axis_ds[3], width, bottom=gap, label="greedy3",color = [pallet[5]])

gap = [sum(x) for x in zip(insertion_axis_ds[0],insertion_axis_ds[1], insertion_axis_ds[2], insertion_axis_ds[3])]
plt.bar(x_axis_ds, insertion_axis_ds[4], width, bottom=gap, label="greedy4",color = [pallet[4]])

gap = [sum(x) for x in zip(insertion_axis_ds[0],insertion_axis_ds[1], insertion_axis_ds[2], insertion_axis_ds[3], insertion_axis_ds[4])]
plt.bar(x_axis_ds, insertion_axis_ds[5], width, bottom=gap, label="regret",color = [pallet[3]])

plt.xlabel('Instancia', fontsize=12)
plt.ylabel('% de utilizacao', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("insertion_ds.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Operadores de Insercao")
width = 0.5

plt.bar(x_axis_ss, insertion_axis_ss[0] , width, label = "random" ,color = [pallet[0]])
plt.bar(x_axis_ss, insertion_axis_ss[1], width, bottom=insertion_axis_ss[0], label="greedy1" ,color = [pallet[1]])

gap = [sum(x) for x in zip(insertion_axis_ss[0],insertion_axis_ss[1])]
plt.bar(x_axis_ss, insertion_axis_ss[2], width, bottom=gap, label="greedy2",color = [pallet[2]])

gap = [sum(x) for x in zip(insertion_axis_ss[0],insertion_axis_ss[1], insertion_axis_ss[2])]
plt.bar(x_axis_ss, insertion_axis_ss[3], width, bottom=gap, label="greedy3",color = [pallet[5]])

gap = [sum(x) for x in zip(insertion_axis_ss[0],insertion_axis_ss[1], insertion_axis_ss[2], insertion_axis_ss[3])]
plt.bar(x_axis_ss, insertion_axis_ss[4], width, bottom=gap, label="greedy4",color = [pallet[4]])

gap = [sum(x) for x in zip(insertion_axis_ss[0],insertion_axis_ss[1], insertion_axis_ss[2], insertion_axis_ss[3], insertion_axis_ss[4])]
plt.bar(x_axis_ss, insertion_axis_ss[5], width, bottom=gap, label="regret",color = [pallet[3]])

plt.xlabel('Instancia', fontsize=12)
plt.ylabel('% de utilizacao', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("insertion_ss.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Operadores de Remocao")
width = 0.5

plt.bar(x_axis_ds, removal_axis_ds[0] , width, label = "random" ,color = [pallet[0]])
plt.bar(x_axis_ds, removal_axis_ds[1], width, bottom=removal_axis_ds[0], label="biased",color = [pallet[1]])

gap = [sum(x) for x in zip(removal_axis_ds[0],removal_axis_ds[1])]
plt.bar(x_axis_ds, removal_axis_ds[2], width, bottom=gap, label="greedy",color = [pallet[2]])

gap = [sum(x) for x in zip(removal_axis_ds[0],removal_axis_ds[1], removal_axis_ds[2])]
plt.bar(x_axis_ds, removal_axis_ds[3], width, bottom=gap, label="pair",color = [pallet[5]])

gap = [sum(x) for x in zip(removal_axis_ds[0],removal_axis_ds[1], removal_axis_ds[2], removal_axis_ds[3])]
plt.bar(x_axis_ds, removal_axis_ds[4], width, bottom=gap, label="shaw",color = [pallet[4]])

plt.xlabel('Instancia', fontsize=12)
plt.ylabel('% de utilizacao', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("removal_ds.png")

# %%
fig = plt.figure(figsize = (9,6))
plt.title("Operadores de Remocao")
width = 0.5

plt.bar(x_axis_ss, removal_axis_ss[0] , width, label = "random" ,color = [pallet[0]])
plt.bar(x_axis_ss, removal_axis_ss[1], width, bottom=removal_axis_ss[0], label="biased",color = [pallet[1]])

gap = [sum(x) for x in zip(removal_axis_ss[0],removal_axis_ss[1])]
plt.bar(x_axis_ss, removal_axis_ss[2], width, bottom=gap, label="greedy",color = [pallet[2]])

gap = [sum(x) for x in zip(removal_axis_ss[0],removal_axis_ss[1], removal_axis_ss[2])]
plt.bar(x_axis_ss, removal_axis_ss[3], width, bottom=gap, label="pair",color = [pallet[5]])

gap = [sum(x) for x in zip(removal_axis_ss[0],removal_axis_ss[1], removal_axis_ss[2], removal_axis_ss[3])]
plt.bar(x_axis_ss, removal_axis_ss[4], width, bottom=gap, label="shaw",color = [pallet[4]])

plt.xlabel('Instancia', fontsize=12)
plt.ylabel('% de utilizacao', fontsize=12)
plt.legend()
plt.xticks(rotation=70)
plt.savefig("removal_ss.png")
